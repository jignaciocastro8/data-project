# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Username = "JanitoElJano"
c.Since = '2021-04-01'
c.Until = '2021-04-25'
c.Store_json = True
#c.Store_csv = True
c.Output = 'data/jano.json'
# Run
twint.run.Search(c)
# Out:
# 1385601820811268099 2021-04-23 10:29:51 -0400 <JanitoElJano> Periodismo de datos me pegó una patá en la cabeza
# 1385290228487888899 2021-04-22 13:51:42 -0400 <JanitoElJano> Yo eligiendo pautas en cualquier ramo
# 1385024851308695555 2021-04-21 20:17:11 -0400 <JanitoElJano> Makina
# 1384717982555852800 2021-04-20 23:57:48 -0400 <JanitoElJano> El hocico me sabe a sangre
# 1384712257842581505 2021-04-20 23:35:03 -0400 <JanitoElJano> @barbaraorvall Barbara hazte cargo
# 1384675765556551682 2021-04-20 21:10:03 -0400 <JanitoElJano> @m0line Culiao con cuea me cabe uno
# 1384119749978693643 2021-04-19 08:20:38 -0400 <JanitoElJano> Me duele el hocico
# 1383598313232953345 2021-04-17 21:48:38 -0400 <JanitoElJano> Veces que me han metido en grupos con muchas páginas: 2  Veces que he participado: 0
# 1383597565396983813 2021-04-17 21:45:40 -0400 <JanitoElJano> No, mi mente es un completo vacío con pausas para pensar en el colo
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_json('data/jano.json', lines=1)
for txt in data['tweet']:
    print(txt)
# Out:
# Periodismo de datos me pegó una patá en la cabeza
# Yo eligiendo pautas en cualquier ramo
# Makina
# El hocico me sabe a sangre
# @barbaraorvall Barbara hazte cargo
# @m0line Culiao con cuea me cabe uno
# Me duele el hocico
# Veces que me han metido en grupos con muchas páginas: 2  Veces que he participado: 0
# No, mi mente es un completo vacío con pausas para pensar en el colo
# @IArraigada1 Cuando era muy chico intenté hacer un graffiti con mi nombre y antes de terminar me dio paja. Tiene hartos significados supongo  https://t.co/hfh0k9w4Jt
# FUE UN GRUPO PEQUEÑO
# Si Greta Van Fleet hubiese existido en los 70s serían una banda de cantos gregorianos.
# Kanye West y Camilo Sesto son los unicos capaces de hacer un disco completamente cristiano que sea🔥
# El covid me cambió el sabor (para peor) de las siguientes cosas:  Coca-cola (humo)  Sprite (humo)  Bebidas en general menos un par de excepciones (humo)  Cilantro (albahaca)
# @rodrigoulloa Pamela Jiles
# ...
