# %% [markdown]
# # **This NB is dedicated to analyze twitter data**

# %%
import pandas as pd
import twint
import nest_asyncio
nest_asyncio.apply()

import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

from utils import*

# %% [markdown]
# # Search using .Near = 'Santiago, Chile' for seven days.

# %%
seven_days = pd.read_csv('data/seven_days_tweets.csv')
seven_days = seven_days[['id', 'date', 'username', 'tweet']]

# %%
seven_days[['date', 'tweet']].groupby(['date']).count()
# Out:
#             tweet
# date
# 2021-01-03   2238
# 2021-01-04  11754
# 2021-01-05  11128
# 2021-01-06  13595
# 2021-01-07  12717
# 2021-01-08  11106
# 2021-01-09  10028
# 2021-01-10   9046

# %% [markdown]
# # **Search: .Geo (beaucheff, 10km) and dates from 'estallido'**

# %%
estallido = pd.read_csv('data/santiago_estallido.csv')
estallido[['id', 'date', 'tweet']].groupby('date').count()
# Out:
#                id  tweet
# date
# 2019-10-14   1513   1513
# 2019-10-15   8444   8444
# 2019-10-16   8756   8756
# 2019-10-17   9657   9657
# 2019-10-18  12015  12015

# %%
# Se filtran los datos
estallido = estallido[['id', 'date', 'tweet']][estallido['date'] == '2019-10-18']
estallido.sample(5)
# Out:
#                         id        date  \
# 7796   1185224335381934086  2019-10-18
# 11384  1185090964601364480  2019-10-18
# 9869   1185168944413511682  2019-10-18
# 11195  1185131559814418434  2019-10-18
# 9180   1185187274595586053  2019-10-18
#
#                                                    tweet
# 7796   @chispavasquez @metrodesantiago En fin, el est...
# 11384  @guille1102 @jtgazmuri @elfrente_amplio @PCdeC...
# 9869   @Humajas @DataRef_ Pero estas hablando de nomb...
# 11195  @Hormiiiguita @MiliEight Pero volviste a Insta...
# 9180   JAMÁS AMARAN A SU EQUIPO COMO LO AMAMOS NOSOTR...

# %%
wordcloud_tweets(estallido, 'imgs/wordcloud_santiago_estallido1')

# %% [markdown]
# # **Search: .Geo = '(beaucheff, 10km)' and dates from 'inicio pandemia' and '8 de marzo'**

# %%
santiago_pandemia = pd.read_csv('data/santiago_inicio_pandemia.csv')[['id', 'date', 'tweet']]
santiago_pandemia.groupby('date').count()
# Out:
#               id  tweet
# date
# 2020-03-07  1477   1477
# 2020-03-08  8827   8827

# %%
wordcloud_tweets(santiago_pandemia, 'imgs/wordcloud_santiago_8M.png')

# %% [markdown]
# # **Search: .Geo = '(beaucheff, 10km)' and dates from 'pero momento de la pandemia 10-15 junio'**

# %%
pandemia_worst = pd.read_csv('data/santiago_pandemia_junio.csv')[['id', 'date', 'tweet']]
pandemia_worst.sample(5)
# Out:
#                         id        date  \
# 29328  1270865410557202433  2020-06-10
# 12995  1271527478130028550  2020-06-12
# 15524  1271458806149664768  2020-06-12
# 9981   1271619113748742145  2020-06-12
# 677    1271938473067458561  2020-06-13
#
#                                                    tweet
# 29328       @cormi2390 Que ricos labios y ese culo...mmm
# 12995  Finalmente, termina mi periodo de formacion.  ...
# 15524  Just posted a photo @ Santiago, Chile  https:/...
# 9981   @Leocamato La naturaleza recuperando lo que es...
# 677                       @franciscoyapo 🤦🏻‍♀️🤦🏻‍♀️🤦🏻‍♀️

# %%
pandemia_worst.groupby('date').count()
# Out:
#               id  tweet
# date
# 2020-06-09  2060   2060
# 2020-06-10  8368   8368
# 2020-06-11  8640   8640
# 2020-06-12  9807   9807
# 2020-06-13  8851   8851

# %%
wordcloud_tweets(pandemia_worst, 'imgs/wordcloud_santiago_pandemia_worst.png')

# %% [markdown]
# # **Search: .Geo = '(beaucheff, 10km)', dates from 'votaciones constituyentes' and .Min_likes, .Min_retweets > 100**

# %%
votaciones = pd.read_csv('data/14_17_mayo_popular.csv')[['username', 'date', 'tweet', 'retweets_count', 'likes_count']]
print(votaciones.columns)
votaciones.groupby('date').count()
# Out:
# Index(['username', 'date', 'tweet', 'retweets_count', 'likes_count'], dtype='object')
#             username  tweet  retweets_count  likes_count
# date
# 2021-05-13         4      4               4            4
# 2021-05-14        14     14              14           14
# 2021-05-15       221    221             221          221

# %%
for index, row in votaciones.iterrows():
    print(row['username'], row['retweets_count'], row['likes_count'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\jigna\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'likes_tweets'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-f5e3241beb8d> in <module>
#       1 for index, row in votaciones.iterrows():
# ----> 2     print(row['username'], row['retweets_count'], row['likes_tweets'])
#
# c:\users\jigna\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# c:\users\jigna\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# c:\users\jigna\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'likes_tweets'

# %%
from utils import *
wordcloud_tweets(df = votaciones, file_name = '', save = False)
