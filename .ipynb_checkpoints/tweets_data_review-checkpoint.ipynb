# %% [markdown]
# # **This NB is dedicated to analyze twitter data**

# %%
import pandas as pd
import twint
import nest_asyncio
nest_asyncio.apply()

import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %% [markdown]
# # Search using .Near = 'Santiago, Chile' for seven days.

# %%
seven_days = pd.read_csv('data/seven_days_tweets.csv')
seven_days = seven_days[['id', 'date', 'username', 'tweet']]

# %%
seven_days[['date', 'tweet']].groupby(['date']).count()
# Out:
#             tweet
# date
# 2021-01-03   2238
# 2021-01-04  11754
# 2021-01-05  11128
# 2021-01-06  13595
# 2021-01-07  12717
# 2021-01-08  11106
# 2021-01-09  10028
# 2021-01-10   9046

# %% [markdown]
# # **Search: .Geo (beaucheff, 10km) and dates from 'estallido'**

# %%
estallido = pd.read_csv('data/santiago_estallido.csv')
estallido[['id', 'date', 'tweet']].groupby('date').count()
# Out:
#                id  tweet
# date
# 2019-10-14   1513   1513
# 2019-10-15   8444   8444
# 2019-10-16   8756   8756
# 2019-10-17   9657   9657
# 2019-10-18  12015  12015

# %%
# Se filtran los datos
estallido = estallido[['id', 'date', 'tweet']][estallido['date'] == '2019-10-18']
estallido.sample(5)
# Out:
#                        id        date  \
# 7946  1185220292903350274  2019-10-18
# 1081  1185333845480095744  2019-10-18
# 2472  1185320465738489857  2019-10-18
# 1391  1185330553538646016  2019-10-18
# 8530  1185204477286072321  2019-10-18
#
#                                                   tweet
# 7946  I'm at Parque Arauco in Las Condes, Región Met...
# 1081  @gmatuscisternas @tere_marinovic @gabrielboric...
# 2472  19:23 en San Joaquín 10-3-1 R3 B10 Vecinal y D...
# 1391  Aparecieron los hinchas de cartón.  Esos que m...
# 8530                                 @rafreak Nojoda tu

# %%
# spanish stop words
stop_words = set(stopwords.words('spanish'))
# join tweets by ' '
estallido_str = ' '.join([x for x in estallido['tweet']])
# split the resultatn text
estallido_list = estallido_str.split()
# lowercase
estallido_list = [w.lower() for w in estallido_list]
# delete @account, stop words and 'https...'   
estallido_list = [w for w in estallido_list if not w in stop_words and not w in ['t', 'si', 'q']]
final_data = []
for w in estallido_list:
    if not (len(w)>=5 and w[:5] == 'https') :
        final_data.append(w)

# %%
# final data
final_data = ' '.join(final_data)
wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color="blue").generate(final_data)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('imgs/wordcloud_estallido.png')
plt.show()

# %% [markdown]
# # Data exploration

# %%
words = []
pinera_count = 0
for tweet in estallido['tweet']:
    if 'piñera' in tweet.split() or 'sebastianpinera' in tweet.split() or 'presidente' in tweet.split():
        #print(tweet) 
        pinera_count+=1
print(pinera_count)
# Out:
# 62

# %%
estallido.head()
# Out:
#                     id        date  \
# 0  1185344791808266245  2019-10-18
# 1  1185344787899211787  2019-10-18
# 2  1185344783088279554  2019-10-18
# 3  1185344773529440256  2019-10-18
# 4  1185344770182266885  2019-10-18
#
#                                                tweet
# 0  @inpolitic El aire está muy pesado con las lac...
# 1  #Cacerolazo Mi barrio caceroleador. Nunca  vis...
# 2   Oh, me acordé de alguien que amaba esos aparatos
# 3  @hectorojas Vio como dejaron la estación de Ma...
# 4  Cacerolazos desde Estación Santa Ana del Metro...

# %% [markdown]
# # **Search: .Geo = '(beaucheff, 10km)' and dates from 'inicio pandemia' and '8 de marzo'**

# %%
santiago_pandemia = pd.read_csv('data/santiago_inicio_pandemia.csv')[['id', 'date', 'tweet']]
santiago_pandemia.groupby('date').count()
# Out:
#               id  tweet
# date
# 2020-03-07  1477   1477
# 2020-03-08  8827   8827

# %%
santiago_pandemia = santiago_pandemia[santiago_pandemia['date'] == '2020-03-08']

# spanish stop words
stop_words = set(stopwords.words('spanish'))
# join tweets by ' '
santiago_pandemia_str = ' '.join([x for x in santiago_pandemia['tweet']])
# split the resultatn text
santiago_pandemia_list = santiago_pandemia_str.split()
# lowercase
santiago_pandemia_list = [w.lower() for w in santiago_pandemia_list]
# delete @account, stop words and 'https...'   
santiago_pandemia_list = [w for w in santiago_pandemia_list if not w in stop_words and not w in ['t', 'si', 'q']]
final_data = []
for w in santiago_pandemia_list:
    if not (len(w)>=5 and w[:5] == 'https') :
        final_data.append(w)
        

# final data
final_data = ' '.join(final_data)
wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color="black").generate(final_data)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('imgs/wordcloud_santiago_pandemia.png')
plt.show()

# %% [markdown]
# # **Search: .Geo = '(beaucheff, 10km)' and dates from 'pero momento de la pandemia 10-15 junio'**

# %%
pandemia_worst = pd.read_csv('data/santiago_pandemia_junio.csv')[['id', 'date', 'tweet']]
pandemia_worst.sample(5)
# Out:
#                         id        date  \
# 12153  1271556362200375296  2020-06-12
# 31449  1270794327590162436  2020-06-10
# 32397  1270761154860797954  2020-06-10
# 11683  1271569891385114634  2020-06-12
# 15977  1271447842658430976  2020-06-12
#
#                                                    tweet
# 12153  @azul_vzla @MissJekill @_YORR_ @SiempreRubor @...
# 31449  15:05 en La Cisterna 10-4-1 R3 BX4 Gran Avenid...
# 32397         Alguien tiene dato de lavandería en Ñuñoa?
# 11683  Que guapo que se ve Lee Min-Ho 😍😍😍 #TheKingEte...
# 15977  @v_viajera Holaaaa amiga cómo estás y cómo est...

# %%
pandemia_worst.groupby('date').count()
# Out:
#               id  tweet
# date
# 2020-06-09  2060   2060
# 2020-06-10  8368   8368
# 2020-06-11  8640   8640
# 2020-06-12  9807   9807
# 2020-06-13  8851   8851

# %%
# Filter date
#pandemia_worst = pandemia_worst[pandemia_worst['date'] == '2020-03-08']

# spanish stop words
stop_words = set(stopwords.words('spanish'))
# join tweets by ' '
pandemia_worst_str = ' '.join([x for x in pandemia_worst['tweet']])
# split the resultatn text
pandemia_worst_list = pandemia_worst_str.split()
# lowercase
pandemia_worst_list = [w.lower() for w in pandemia_worst_list]
# delete @account, stop words and 'https...'   
pandemia_worst_list = [w for w in pandemia_worst_list if not w in stop_words and not w in ['t', 'si', 'q']]
final_data = []
for w in pandemia_worst_list:
    if not (len(w)>=5 and w[:5] == 'https') :
        final_data.append(w)
        

# final data
final_data = ' '.join(final_data)
wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color="black").generate(final_data)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('imgs/wordcloud_santiago_pandemia_worst.png')
plt.show()

# %%
from utils import*

# %%
wordcloud_tweets(pandemia_worst, 'jajaja')
