# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')

# %%
x = range(10)
y = np.arange(10) * 2
plt.plot(x, y, '-o')
for (x, y) in zip(x, y):
    plt.text(x, y, 'hola hola')

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('spanish'))
#stop_words

# %%
np.random.randint(3)
# Out:
# 1
