# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
import requests
import re

# %% [markdown]
# Corpus: The corpus here is an entire book and it is received as a large string.

# %%
r = requests.get("https://data.heatonresearch.com/data/t81-558/text/"\
                 "treasure_island.txt")

# raw_test is essentially a large string.
raw_text = r.text

# %% [markdown]
# Here we take lower case to every word in the text and then eliminte the non-ASCII characters.

# %%
processed_text = raw_text.lower()
processed_tex = re.sub(r'[^\x00-\x7f]',r'', processed_text)

# %% [markdown]
# Here we create dictionaries to assign id's to every character in the text.

# %%
print('corpus length: ', len(processed_text))
chars = list(set(processed_text))
char_idx = {c: i for i, c in enumerate(chars)}
idx_char = {i: c for i, c in enumerate(chars)}
print('total chars: ', len(chars))
# Out:
# corpus length:  397419
# total chars:  67

# %% [markdown]
# They define sequences of characters of length max_len from the text taking steps of size step.

# %%
max_len = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(processed_text) - max_len, step):
    sentences.append(processed_text[i: i + max_len])
    next_chars.append(processed_text[i + max_len])
    
for i in range(0, 4):
    print('sentence: ', sentences[i])
    print('next_chars: ', next_chars[i])
# Out:
# sentence:  ï»¿the project gutenberg ebook of treasu
# next_chars:  r
# sentence:  the project gutenberg ebook of treasure
# next_chars:  i
# sentence:   project gutenberg ebook of treasure isl
# next_chars:  a
# sentence:  oject gutenberg ebook of treasure island
# next_chars:  ,

# %% [markdown]
# Vectorization:
#
# The first dimension of x represents which sequence we are looking at, the second the position in the sequence and the third is which char is the said position and sequence. Then, $x[s, p, c]=1$ if and only if the character with index $c$ is present in the position $p$ of the sequence number $s$.
#
# In the same spirit, $y[s,c]=1$ if and only if the char $c$ is the next char of the sequence $s$.

# %%
x = np.zeros((len(sentences), max_len, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_idx[char]] = 1
    y[i, char_idx[next_chars[i]]] = 1
print(x.shape, y.shape)
# Out:
# (132460, 40, 67) (132460, 67)

# %% [markdown]
# Build the Deep Learning model.

# %%
model = Sequential()
# First layer: lstm.
model.add(LSTM(128, input_shape=(max_len, len(chars))))
# Second layer: dense with ouput dimension len(chars).
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               100352
# _________________________________________________________________
# dense (Dense)                (None, 67)                8643
# =================================================================
# Total params: 108,995
# Trainable params: 108,995
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The next function takes the output preds from the neural network and then, using its values, assign probabilities to each value in the array. Then, sample from a multinomial random variable with this probabilities.

# %%
def sample(preds, temperature=1.0):
    """
    Given the array of preds, assign probabilities to each
    value. Then, with this probabilities samples from a multinomial
    random variable.
    """
    preds = np.array(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    """
    """
    print("******************************************************")
    print('----- Generating text after Epoch: %d' % epoch)
    start_index = random.randint(0, len(processed_text) \
                                 - max_len -1)
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----- temperature:', temperature)

        generated = ''
        # takes a random sentence from the text.
        sentence = processed_text[start_index: start_index + max_len]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
    
        # completes 400 characters of the random subsequence of the text.
        for i in range(400):
            # create a x-data of size one.
            x_pred = np.zeros((1, max_len, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_idx[char]] = 1.
            # predict the output.
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            # get the char with the index given by the NN.
            next_char = idx_char[next_index]
            # add the generated char to the text.
            generated += next_char
            # delete first char and add the added char.
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
# Fit the model
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1035/1035 [==============================] - 47s 44ms/step - loss: 2.4550
# ******************************************************
# ----- Generating text after Epoch: 0
# ----- temperature: 0.2
# ----- Generating with seed: "ould any be intended. he turned and spok"
# ould any be intended. he turned and spoke the stread the shore the streed the still the shop to the said the stread the doctor the strome the shore the strear the shope the shore the shoped the stroog the streed the strome the strook the more the shore the said the strought and the strest the shore the start to the street the shop the shop the strome the strome the strook the shop the stread
# and the shout the strome the stread the shop
# ----- temperature: 0.5
# ----- Generating with seed: "ould any be intended. he turned and spok"
# ould any be intended. he turned and spoke in or said
# steed and the coom and the hore
# come here there sadest in the bock, and the coars out the good the said
# connor soon and the shep to the said the canning then the stip, and he
# conten and it was starl head the said tere the poore and me to come and the stood the stook it in the seal the say to the said to geal he couss for the spipse the
# captain and the more to sholld we look and
#
# ----- temperature: 1.0
# ----- Generating with seed: "ould any be intended. he turned and spok"
# ould any be intended. he turned and spoking bever. and me destreid be yousd the tringed he datt, "had to, ap"and a covest had then
# deceb. he
# soctort, and the osheat'd sim, custhen
# runtit-!
#
# "becide way oupl dear up wor ?wey ancay, flet it bryss to grong with to be."
#
# and the proap.
#
# you hey ; i come-stont as beation; und come loscor, "you tearsmow hey dea
# i shime, you some--the rraised to mestan more
# andcher, towlly thaid
# fo
# ----- temperature: 1.2
# ----- Generating with seed: "ould any be intended. he turned and spok"
# ould any be intended. he turned and spoked
# "now ro. wae ecent in sre get the ceptaaling the
# oll. as usst gope, and pig oad, in lapsty brand. i'm theive hep riccketke. uc." dupp, silvees elce that amkittlosp.
#
# shnos ovly, or es
# tos.
#
# "renolderst bechore im cuv--what b
# londer, "tom't bosly nolphiss dosk, umharby yould
# wot pexatily
# wit wisi,
# tho clistly, an
# the po'i; pee it grougat.
# so sluid, thend, at my blisk to
# of aur2ted
# Epoch 2/60
# 1035/1035 [==============================] - 41s 39ms/step - loss: 1.6901
# ******************************************************
# ----- Generating text after Epoch: 1
# ----- temperature: 0.2
# ----- Generating with seed: " maker. at the end of the straits i made"
#  maker. at the end of the straits i made the was
# the ship and the said the said and the seemed the ship and
# the sand the ship," said i was the steemed the captain of the said and the silver to the stockade.
#
# "and the captain silver on the sand the shoulder on the said and the say of the ship and the ship, and
# the shoulder to the ship and the ship and the ship, and
# the still to the said of the ship and the ship and the said the doc
# ----- temperature: 0.5
# ----- Generating with seed: " maker. at the end of the straits i made"
#  maker. at the end of the straits i made be to the bestred to the a sea rong and
# what reming on the sim. and i was posself, on the doctor
# stip of the red. the dan that i had to feet the
# seamed to the captain and the doctor to stand the botter of the onch of our of the six had a captain on the inlengland.
#
# "but if i was head entland the stocked the treat on the captain the
# for the said on the shoulder of him stood had stolder and t
# ----- temperature: 1.0
# ----- Generating with seed: " maker. at the end of the straits i made"
#  maker. at the end of the straits i made rulver
# neist founten dost eye our reision, pawsided by the knew opers, and set side at stiffel, neat the
# rastre carned of stocpesed the hunking to the
# spatret; we placearion of your bming itselftil the
# warys wring-turranty with the cap hasted swmas do it
# the mighters mave
# he, down
# betaid, and point was sake man their watired from a mast out
# but about ever thet it were for any off mourt.
# ----- temperature: 1.2
# ----- Generating with seed: " maker. at the end of the straits i made"
#  maker. at the end of the straits i mader back
# up incermentaos ourmpard the
# was hhad dreeet. when then orrugh," repuddes, whened in; and upreobide on  ifgutentior. "we knet. they wrelage
# to a part from jeated. on the powd thinm.
#
# thick.usive way, time a  in louns!" said dictor sostled to of the cartinyel nd't by
# endros onty. "and," rade of a blitt," stipper us doomcaoliflace rack."
#
# "domause put of i deal -he be lasts she frepte
# Epoch 3/60
# 1035/1035 [==============================] - 60s 58ms/step - loss: 1.5350
# ******************************************************
# ----- Generating text after Epoch: 2
# ----- temperature: 0.2
# ----- Generating with seed: "oughout.
#
# "what i can do, that i'll do"
# oughout.
#
# "what i can do, that i'll do the captain we say a man to the doctor.
#
# "as so the squire of the said the sunder the man the captain with the sand the captain with the stire of the stern the sand the cold. the sand the store of the sand the sand the
# cold stand the colard of the streement the sand the sounder of the store of the stire of the said the signal to the sand the still the signal the captain was the stire of the ma
# ----- temperature: 0.5
# ----- Generating with seed: "oughout.
#
# "what i can do, that i'll do"
# oughout.
#
# "what i can do, that i'll do jim. says i don't the ship and the deck ever fire canner.
#
# "think he said all had corred him hands the captain
# man's better the choors and the man smance of the surrant of them two before and into the down the
# came he had been gown of the project gutenberg-tm him the userest as should have silver and the island, in the crist of the
# same like see a sound.
#
# all the man with the mun't colle o
# ----- temperature: 1.0
# ----- Generating with seed: "oughout.
#
# "what i can do, that i'll do"
# oughout.
#
# "what i can do, that i'll donn m," said hef
# near of a mage.
#
# there's bost me that't swall, silver'l as the way of issiding way been mes
# duy, unthe that. but they sace shouth 't mened the neck after notiset, and
# a going among our swaps by it stand to me was among the  ch woubt behand traumse there's rimen, returned founding cocks; and a
# compannien, and men't that that i and obs weeks in the captain
# ca'rn obere full pro
# ----- temperature: 1.2
# ----- Generating with seed: "oughout.
#
# "what i can do, that i'll do"
# oughout.
#
# "what i can do, that i'll don we's keep rome9t puttily.
#
# "why see. all.""allosted my leaving s mycule to man. fird, course and.pbelbenebler in himh's old me--the colartien,
# carenund why't.
#
# he could to hold knew jasty, and geen. nal, gawkst mind where wry duniont way and oft cyos with
# the poril worls for i !ad." cryweyed; .     heid memen aboacdouny board myself; and coving merep-besores. i, there smone.
#
# ay's me.
#
# Epoch 4/60
# 1035/1035 [==============================] - 66s 63ms/step - loss: 1.4631
# ******************************************************
# ----- Generating text after Epoch: 3
# ----- temperature: 0.2
# ----- Generating with seed: "ays i; "i'm not going back to captain ki"
# ays i; "i'm not going back to captain kind of the sound, and i was a sea suppored the captain of the sand of the sound of the stranted to the boats of the stern and the captain something to the boats of the man to the captain to the boats of the sound, and the man to the tood of the spired and the captain and ship or and so that the captain and the was of the ship and so that i was a captain and the captain and the store of the store, a
# ----- temperature: 0.5
# ----- Generating with seed: "ays i; "i'm not going back to captain ki"
# ays i; "i'm not going back to captain kind of the capeats of a singlemins head me of in the for the black to the ars of the his face, and the ship and i had a fat hang the store and the possessels,
# and standed and the face, and then the sour here was a bear our and the ship to and or a ship ent as thought from the store of the clear of the black long a
# contacied and he had a griess of the signed from a bight from the done.
#
# "i was t
# ----- temperature: 1.0
# ----- Generating with seed: "ays i; "i'm not going back to captain ki"
# ays i; "i'm not going back to captain kipted, but lints wouldeds a swert or or firs. manting cut in as
# and some of the dead of the ship before were which at the worle
# score, i hear by head knetched by thought, and healtifn what round. and
# folled old a seel. the man had and preted
# of the owreend.
#
# "as you're do no tear or like a man with east, and
# didg towetce lay in thees made barge on ferrits of again. "it was the for fain a mat
# ----- temperature: 1.2
# ----- Generating with seed: "ays i; "i'm not going back to captain ki"
# ays i; "i'm not going back to captain kind almost' left's; i wad a terr
# argly that let himsey, quiet
# the dicked by iscone wy
# this was to hight. him, snok, and then string leemed" curreces thus wolless,
# upon on his
# expicty of a cotsod, joyces'lf sexifiity.
#
# "mibve this here, "i retuch longis-; now, down to cairieps a piece
# light. all itsone with of neit nowly, toil of up i canfeath of sack. all his one,
# greasurrake over, -ilvose
# Epoch 5/60
# 1035/1035 [==============================] - 51s 50ms/step - loss: 1.4175
# ******************************************************
# ----- Generating text after Epoch: 4
# ----- temperature: 0.2
# ----- Generating with seed: "still. she headed nearly due south, yawi"
# still. she headed nearly due south, yawing the stockade of the stipped and the captain's the captain and the copser the captain
# and the captain or or along the captain had been seen the still be boy and a sure than the captain to and the captain had should should should have the sterned the stockade of the captain, and a boy. the captain had taken the captain had taken the stockade by the captain had to feel the captain had taken the s
# ----- temperature: 0.5
# ----- Generating with seed: "still. she headed nearly due south, yawi"
# still. she headed nearly due south, yawing the place of the face of the store, and the captain, and then i began to good the strangers in the
# conical sure cut the coldowadd upon the captain
# with a reckess to deserved the sea--and the chopt of blind and sea put the colder broughter and so cap'n i should last we was blow on the place to the captain's treet of the captain. "the doctor preton the manch each of the took on the mollect side
# ----- temperature: 1.0
# ----- Generating with seed: "still. she headed nearly due south, yawi"
# still. she headed nearly due south, yawing the island on should lees enough it or two sea, in't thought asheied--
#
# "piecan we blow
# and it's fear xpire. time are afvolrolf us or mschirversicalf as i
# anyternterted with up
# this and the curren. yo shipmay?"
#
# with a already on child ?"pied; "i deseled must aboard?" he added; "nojoy, sir's fhane. "he't's completh
# he mudde
# or very been and shocting that and dover in the
#
# away in a
# ----- temperature: 1.2
# ----- Generating with seed: "still. she headed nearly due south, yawi"
# still. she headed nearly due south, yawilll about you
# boy?.
#
# "you, he is illuted one rokeleglidath, speedys him  accorded my he
# unquarted with i have shores alhimp and benw were dissupandly withousk, same wrifted
# furi my neal tlem, iiraly oud tooks proven eached duclaw--helk ol and no fleel
# a good them deer ruther odds, upon xi
# :first upon to very ashed youten agai ssufally--put you'll all be
# on beging knew regird, and offs; we
# Epoch 6/60
# 1035/1035 [==============================] - 36s 35ms/step - loss: 1.3785
# ******************************************************
# ----- Generating text after Epoch: 5
# ----- temperature: 0.2
# ----- Generating with seed: "spring welled up into an artificial basi"
# spring welled up into an artificial basing the strangers, and the captain with the ship with a second that had the captain.
#
# and the captain to a see had seen to the captain had the captain and the man with the strangers.
#
# "when," said the captain had a strong the stockade and so that i had the ship with the strangers, and the shore was the ship we were the stern of the stern of the stame in the strangers.
#
# "i was stood of the squ
# ----- temperature: 0.5
# ----- Generating with seed: "spring welled up into an artificial basi"
# spring welled up into an artificial basint the feel of the man with the low of doubt in the mount of the mutiny the chire of the sand; the doctor doctly he rate on the sea-way of the stern of the sonts of the spires of the mount with the round of the thing sollection.
#
# and her could hear the man to pats the strangers of the using the possible to the man of the last that had a man to me the captain with a farrs and struck on the posss
# ----- temperature: 1.0
# ----- Generating with seed: "spring welled up into an artificial basi"
# spring welled up into an artificial basitty, and, add he sudden pare, far a husreth sea-comport his note side up dasp.
#
# "when you don't posy my the captain.
#
#     "to., body ad possives in last any compled absurarly,
# nor swilly till heat soon when he went to
# mater. ary excorely in his, up, i blamsed when the wise mattinaless sitgrksprit.
# and i could were owbergrindl self well, tire here of our
# higment."
#
# jow it crought on the b
# ----- temperature: 1.2
# ----- Generating with seed: "spring welled up into an artificial basi"
# spring welled up into an artificial basise, of most and or then
# so had heuking befor onchs, and they last, jig. he had thought
# howes and a fubreand; doctor bather--i
# having-d prith as the corncr. to hears from
# hrissporaio, and you woulded untile would for his every
# or his macker evey the rold intoccilding lotted aftee
# kind-fulle agood lony soonsured uptorst, you weys
# old--
#
# he head dead in be at me; if
# ' misked knicking blamp
# Epoch 7/60
# 1035/1035 [==============================] - 39s 37ms/step - loss: 1.3522
# ******************************************************
# ----- Generating text after Epoch: 6
# ----- temperature: 0.2
# ----- Generating with seed: "ve against three
# leaves us four to nine"
# ve against three
# leaves us four to nine the worl of the store of the works of the southe show to the wood of the woods with the stores of the water. the ship with the stores of the stern hands of the ship
# with the woods of the world for the southe the wood of the works of the stores of the had the same the store of the stores of the works of the and some of the stern
# the store of the woods of the other the doctor livesey, and the doc
# ----- temperature: 0.5
# ----- Generating with seed: "ve against three
# leaves us four to nine"
# ve against three
# leaves us four to nine to the doctor--had he gave a boats, and the rest on the ship
# with his mouth. like the old make the last tom his
# seating the wast of the ship, and the doctor with the hand.
#
# "now, it's bost the sune my hand. all the colard before in the half-had mistered a moment in there was a runders and terror. and
# here the began to the stockade in our life, and we said
# the for a man with the colard for t
# ----- temperature: 1.0
# ----- Generating with seed: "ve against three
# leaves us four to nine"
# ve against three
# leaves us four to nine. you'll have a co,chayern fird of a picture and mend gertl, he faunt, very glad,
# indeed's myselabard and mind above a fort, they moon you shall keep together top hill and wait ever
# hon't . ton witho-gorg two running riighers,
# and silver. so xill the precaot.
#
#                                       pxpem. th,
# ship--too perhaps time that he would sove his heaging began to a wlet blind before d
# ----- temperature: 1.2
# ----- Generating with seed: "ve against three
# leaves us four to nine"
# ve against three
# leaves us four to nine i sthinks, and leg't skinss. itckil his
# woon party adming heaverarsh i hat his matem with m
# aboars a boot, from our bast. yet were ip
# rally after rad my upong, nlint cingurst, and
# the prettinus dook. i'll have alam. wede fatered with th moars goat.
#
# told -han the wide find, the half, or more soint of
# his kay pornated. it was plear reyles cap'n all the
# captain.  he could be sk we stot o- o
# Epoch 8/60
# 1035/1035 [==============================] - 89s 86ms/step - loss: 1.3287
# ******************************************************
# ----- Generating text after Epoch: 7
# ----- temperature: 0.2
# ----- Generating with seed: "th his crutch
# under his arm, and at onc"
# th his crutch
# under his arm, and at once than and the captain winded of the strees than the shore was the captain with a black of the strande silver; and the captain was the captain to me to see him as i was silver and the captain. "silver and the captain was the ship was already to his beckest to the ship for the captain with a black of the streams in the stores of the same shore in the same man the captain. "and well, jim, jim, i cou
# ----- temperature: 0.5
# ----- Generating with seed: "th his crutch
# under his arm, and at onc"
# th his crutch
# under his arm, and at oncast and the lands i to canner and the ship. the deck.
#
# "that we can the doctor man ben guar--ben
# the squire and the captain as i began to his best of the spit of the stores, and when the warf of the stirms of the sea his words of the
# ship we could have heard the captain to sear to the squire and man to me that we had the far my farren come of the ship behind, that the captain. i could be incan
# ----- temperature: 1.0
# ----- Generating with seed: "th his crutch
# under his arm, and at onc"
# th his crutch
# under his arm, and at oncaes- shore. crew heat once beliek. the island, now, leg to the buccaneers crue?
#
# there was no hips no to mourage. but first showed got as might to
# skrowernore swore donstrim's, dis awranged. acceint, day off
# the cold; an oy. set found on this man and
# captain was almouth was feet out of the nambor, in himrese, and round, wind electronic
#  the ontule, and bustuccuring, without where me silvered
# ----- temperature: 1.2
# ----- Generating with seed: "th his crutch
# under his arm, and at onc"
# th his crutch
# under his arm, and at once to give his kees than by
# what do ever before i
# and hepping,"     "dire that i obe store pationak eart; why
# lies toven bechinate bew happeer raven over, and
# theefore the corard inctoke to hert, well, and crembly
#  lew, bening his creat; but ebornes our eccoust,
# ifly seak lacklichation; but as pever of clex, glam some mind haw of
# wun sefounded in the doctor faiflay to us a reach
# bunn's pott
# Epoch 9/60
# 1035/1035 [==============================] - 65s 63ms/step - loss: 1.3132
# ******************************************************
# ----- Generating text after Epoch: 8
# ----- temperature: 0.2
# ----- Generating with seed: "we had laid him down in the log-house to"
# we had laid him down in the log-house to have that i had sailor a good something to the ship of the spring to the ship of the ship of the spring of the ship of the spring to a seamed the captain, and the captain, and the cold of the coracle to the ship of the ship of the spriped
# them the captain, and the captain, and the captain set of the strait; and the captain, i had to go to the ship of the ship of the
# stranger. the captain, and t
# ----- temperature: 0.5
# ----- Generating with seed: "we had laid him down in the log-house to"
# we had laid him down in the log-house to the doctor was no up him and of the work of course, that he had not one of the strait-black of the survery
# some were with the same bow, and the colds, that is a pewing here were of the more, and the doctor like that seen the ship in the strake to the shirder and some in the more than in a monty my own take the criess, and the mouning and that that i don't and
# took all for the captain, and i too
# ----- temperature: 1.0
# ----- Generating with seed: "we had laid him down in the log-house to"
# we had laid him down in the log-house together, mr. trelawney; she asked tofthere in my pood
# and to had has island, we part any burning first were.
#
# "but, done seny set hands, than if in ceeck,
# you have the sea dold fees passerned brisk of their streamd to
# msquarenerless, with than to trumbing than i could
# not like the work
# besides, with saying."
#
# "now, you could never again had enece tage, and if eithered lumples.
#
# and the s
# ----- temperature: 1.2
# ----- Generating with seed: "we had laid him down in the log-house to"
# we had laid him down in the log-house to
#  i loeminly dangedly,
# ow--leith, 'uch . remominerity.ety wented's possust sleels an a.
#
# "nord's treely to couldsded, three to he had ext my old prosming-buccadale we clu some told up a parser
#
# twleaking ear attalleck ofper!" cried wete hange soul, and a mull hat i
# was, would beon, peture upon me, evey sho'
# a seeming. him him--told seamark't. be out for lies, when you'll
# must, erecaot, in
# Epoch 10/60
# 1035/1035 [==============================] - 53s 52ms/step - loss: 1.3042
# ******************************************************
# ----- Generating text after Epoch: 9
# ----- temperature: 0.2
# ----- Generating with seed: "is flint, i suppose?"
#
# "heard of him!""
# is flint, i suppose?"
#
# "heard of him!" cried the captain of the stremed to the shore the woods of the same man the woods, and the door, the door, and the ship on the short of the seamen of the same man the shore of the shore the ship and the ship and the ship on the short of the shore the shore the dead of the shore and the shore the shore and soon and so the treese in the ship of the ship and so the woods of the short and so had to s
# ----- temperature: 0.5
# ----- Generating with seed: "is flint, i suppose?"
#
# "heard of him!""
# is flint, i suppose?"
#
# "heard of him!" cried the squire and the more the doctor spit a surming the shoulder hear a party the captain with my fee to the dead and stored me in the woods had to get like a project
# gutenberg-tm hands and place and the head sure him and able the other shill were moment he was a good the woods hands to me like which the inn we called
# to a seamseded the captain with the shit so he was sooner and the same ma
# ----- temperature: 1.0
# ----- Generating with seed: "is flint, i suppose?"
#
# "heard of him!""
# is flint, i suppose?"
#
# "heard of him!"
#
# "we she rekend, sir," he saidiny il of the shore proberred of the
# wash, abspilfore to sueted danger money i was, i can no up the lilleners on the sive grest, and we wellet' comeasterichg turetted of"self positions good, and the meredy-to
# share's sholletter hands
# the follour cap'n trees; you caneruned water excitted with
# the gallees. he reose pain rane an ballea' leture, and seamented in a
# ----- temperature: 1.2
# ----- Generating with seed: "is flint, i suppose?"
#
# "heard of him!""
# is flint, i suppose?"
#
# "heard of him!" cried the moon diegg, and ned nattrle trees and most thundersone, along his pa island, the teice he fresp hears
# verrilllfl; and i porn unter one very head of
# very terms and so neteled filled man he mark it
# hands helped? and what ectil silver, he seen my shook; benier the
# tripped up, elaying over the fairade--leck, encross, timber, slascies hands, timeb. we stood up a me; the pirates of
# mquar
# Epoch 11/60
# 1035/1035 [==============================] - 55s 53ms/step - loss: 1.2837
# ******************************************************
# ----- Generating text after Epoch: 10
# ----- temperature: 0.2
# ----- Generating with seed: "by what dangers--i felt ashamed
# to look"
# by what dangers--i felt ashamed
# to look the ship, and the whole was all the ship of the ship of the strain.
#
# "the squire in the ship, and the sust the ship of the blood--the streemed to the more of the strain. i was
# still the shore should see his horse of the story
# to the suning the streat of the ship of the ship of the ship of the ship of the ship of the ship of the ship of the ship of the for the ship of the store of the ship of
# ----- temperature: 0.5
# ----- Generating with seed: "by what dangers--i felt ashamed
# to look"
# by what dangers--i felt ashamed
# to look the water his missy behind the morning in the word he was breakless. and
# any long john of the shore for me to see the blast of the bothers.
#
# the doctor livesey take end me in the strain. it was
# in the word he was the souther as i suppett the
# more was on a both of the ship of the shoulder the sound as shout
# and silver with the timbers, and more of the black
# that i had had to see for the att
# ----- temperature: 1.0
# ----- Generating with seed: "by what dangers--i felt ashamed
# to look"
# by what dangers--i felt ashamed
# to look with the tume and a mishatime of entrerts for , up,ny
# when, to call he strose bonning or along him posising, and
# the captainy behind with any fattle these, somethe fa? his
# good enty laug doctor slipped my deet.
#
# "ah. i have, and all made or abupted or redisy in the bund as in a shone for
# the plocked would; for, the norst in against
# there, he was aim with thundering, it was puting
# each han
# ----- temperature: 1.2
# ----- Generating with seed: "by what dangers--i felt ashamed
# to look"
# by what dangers--i felt ashamed
# to looking from. gentlem i
# ?haaddily daik ag for, bentlust eplory athor on the chishtoos exe ply formidaged coadding, scooded
# our behish, in us admed pup huwhore how perrest. isquip he bit upter
# "when so starming shopes nughing right reminks
# we let, answer a ted a wite of somet in ginple szxcomp of the him of now i knife remught
# your wat me, i can't be
# tell lier upon his ess, see escoug he cold in
# Epoch 12/60
# 1035/1035 [==============================] - 50s 48ms/step - loss: 1.2791
# ******************************************************
# ----- Generating text after Epoch: 11
# ----- temperature: 0.2
# ----- Generating with seed: " he sat, took certain bearings with his "
#  he sat, took certain bearings with his complesions before the ship and shouting and shouting and captain should say, and i had to sign of the captain.
#
# "well, you, silver strode the same moment in the ship of the ship
# the captain. but i could not been the ship of the ship
# straight before the captain. but the same that he had the ship that i could not the blockhouse, and i should let the man strong the coracle and the was before the
# ----- temperature: 0.5
# ----- Generating with seed: " he sat, took certain bearings with his "
#  he sat, took certain bearings with his chest. it was not her
# of a good rate and the ship bost out his much had all had thought it of the safe our lives of the world and all round the colard men to have you that complest of the worst of councious of for me and a shad sea-chile his had two sunson, observed in the same troubhes his crutch the covacly
# and all that this than that's the sea-cook, long perhaps with the captain.
#
# "what i t
# ----- temperature: 1.0
# ----- Generating with seed: " he sat, took certain bearings with his "
#  he sat, took certain bearings with his share as doubloaid,
# gule, seconds confile to put llimilingtrapheady to chose the bows table. curt, take
# his teress. quite of firecon, and, daiss on could have
# only loaks. and the rest of their
# smotions no us as i low in a money, and its
# a had easening last i knithing a manner, but i
# had then set stuck the neacer grow crowbesshigh suppoact, as bound out her
# of this
# hiding many ston't dock o
# ----- temperature: 1.2
# ----- Generating with seed: " he sat, took certain bearings with his "
#  he sat, took certain bearings with his neck, sway.
#
# "no long "again, good, we'll lask hirsness.
# had get trat xwas, before strong struck a how her b
#   xxfiie brack no excerion wegh, and new we coufsted in
# the fellors. it back to you. why had a niwors.
# bun bull, itt's down our terrowl.ab
# fribarning, how my f binging, chein ta-wash intluds mecritimes. having
# my brdag-in their cover. camy raiser to my gentlth passed, courss
#
# Epoch 13/60
# 1035/1035 [==============================] - 61s 59ms/step - loss: 1.2672
# ******************************************************
# ----- Generating text after Epoch: 12
# ----- temperature: 0.2
# "---- Generating with seed: " another thought into my head which was
#  another thought into my head which was
# the same more the captain standing the spirits, and the same more than the same good to the strait of the same more than and sure the captain had take the same more than and sea-no fire, and the man along the said, and the last could have the said and the captain spirits, and the same more than the same more to see the ship's end of the captain still the same more than the spirits in the strait.
# ----- temperature: 0.5
# "---- Generating with seed: " another thought into my head which was
#  another thought into my head which was
# almost served in the shore's on a moment
# like a quier to cheer his cap'n the using of the streeling spranger on the work of the rest. you can't lay a bottle. we said to a bit of my buccaneer still
# began to sailsh of the trick, and the old
# the man of the ship, and i had
# no have four lost the wind, and recainly steps of the ships-assed the destrotions the beggasther in a bottle of the sun was a
# ----- temperature: 1.0
# "---- Generating with seed: " another thought into my head which was
#  another thought into my head which was
# knee soting betweer already and fairon wen, pipes desired, i that.
# he mind that when i began to cutlet in a man
# along surfing in the powder frigh youn achious
# reeld ipprisiessed in
# diskned ivhing again and singer. it was,
# the ship--
# hos rediment purslets missove in the listed the sy
# lugit
# ever mind the mealy continus, accind, and good began to lumber, sure the current brokenture ben
# whe's
# ----- temperature: 1.2
# "---- Generating with seed: " another thought into my head which was
#  another thought into my head which was
# ustradist in'n been doctor, the current conhe deciqusroticular bequint, thpand in
# a aabon you disprisebage, whind in, as i hot eunlided.
#
# on one back on the black fl. had lay you
# fereccil dostidg o' filder. and london, was,
# ons. i stredly, you skillilry the walfed it face-- and joyce in the oat, and flengen, it isouthatly oh dick, banks here ropes, prospery. crewing, and
# holtidle let's," re
# Epoch 14/60
# 1035/1035 [==============================] - 80s 77ms/step - loss: 1.2606
# ******************************************************
# ----- Generating text after Epoch: 13
# ----- temperature: 0.2
# ----- Generating with seed: "our pardon."
#
# "i have a chart here," s"
# our pardon."
#
# "i have a chart here," said he, "they was a still was the ship
# and the ship we had the captain with the same the same the corrors, and the captain smollett of the poor of the streng of the ship
# we had the same sent to the same the sound, and the man of the same the same the stern of the stern and the corrors, and the same half the same to the ship
# the stern and he was still to the ship we had the same half a man make
# ----- temperature: 0.5
# ----- Generating with seed: "our pardon."
#
# "i have a chart here," s"
# our pardon."
#
# "i have a chart here," said he, "well, you says, for the first of a silver stores to him and to the doctor.
#
# a long says were silver said weated of the ancers of the ship
# the stern of the same to a growent, and for this time he had had to the old face of his brickered as the sound of the woods for the sand, we can't a takenes, and so he was
# the dead was coning to the wood--the other side of the thing of of the partic
# ----- temperature: 1.0
# ----- Generating with seed: "our pardon."
#
# "i have a chart here," s"
# our pardon."
#
# "i have a chart here," said took my di. he trinles. ihous keeping halmst in night among at doing like the heave excape as they fell more done thatchans onced joll! says abrome like a binds for the wasitees.
#  almons any will and the wood--hule, "their
# were cap'n make gentlemen my barreth, if
# we wish i had been to very boughswain, as he meated cast as ay, yourn
# pulled before enough was alive eared fister to thk blind i
# ----- temperature: 1.2
# ----- Generating with seed: "our pardon."
#
# "i have a chart here," s"
# our pardon."
#
# "i have a chart here," said he--now then; he's halruvement and bysoon
# still huse looked ho-e of for, they ain-wast luod of fourrimpy. the
# joyised his mlink, feep "all about caugh. how it was nhishore
# chestly then dreath, run to jiw to run, and ren you
# hat last, john, was all agoemed you, and my hands
# ouh wellich to our ancor len for dearatient.
#
#      ?"this island i needding lying brandy, this time we -bout the do
# Epoch 15/60
# 1035/1035 [==============================] - 85s 82ms/step - loss: 1.2466
# ******************************************************
# ----- Generating text after Epoch: 14
# ----- temperature: 0.2
# ----- Generating with seed: " when.
# here's a first-rate seaman, cap'"
#  when.
# here's a first-rate seaman, cap'n have a man of the same man of the ship of the ship of the stern to the sont of the ship of the side of the ship of the other side of the sea and so that the same man of the sea shore were the captain, and we were a seamen to the same man of the ship of the house of the ship of the same moment the side of the ship of the ship of the sea side, and all the same man of the ship of the ship, and we h
# ----- temperature: 0.5
# ----- Generating with seed: " when.
# here's a first-rate seaman, cap'"
#  when.
# here's a first-rate seaman, cap'n. we had the three started to a go far of the shipand of the found expose beside the stern and at that of the water, and if it in a
# deady not a coward foundagn. the doctor something the stern a sides of the side of the stern to the excattie there was a little the thing seamens of the lunt of the doctor, and i had a boot of the sea.
#
# "my draw," said he, "i could be the other was still and after
# ----- temperature: 1.0
# ----- Generating with seed: " when.
# here's a first-rate seaman, cap'"
#  when.
# here's a first-rate seaman, cap'n youmagine of stand of bone groy
# else of from the pieted wrintful to the etside, seet an horraid, but for her seg to
# shay, and shot he got this the second boatd
# its
# through before noth, more flew a gialted what it."
#
# they's the worst for the sinting in any hears yourth
# inn, hands one of the turnor place, whith a
# chair, neither that the deremitacing woilling. i was not ound for fight. what
# ----- temperature: 1.2
# ----- Generating with seed: " when.
# here's a first-rate seaman, cap'"
#  when.
# here's a first-rate seaman, cap'n xwihe fast his creaking of eacal blochh. the onlibg as
# same isumat grue, kneelely; tolly "the derrmint sitting piesgride of thaculed bunging, and alay sullork me--he a chisca
# abonusrated poss, and hold runt, -none god up this
# was let round, donnily hands's, rung herus little walking knockment been
# hands for me sight end-biccidicaraks along his
# ngrooted efpired obsiravicy.
#
# incesirals lews
# Epoch 16/60
# 1035/1035 [==============================] - 41s 39ms/step - loss: 1.2402
# ******************************************************
# ----- Generating text after Epoch: 15
# ----- temperature: 0.2
# ----- Generating with seed: "if jim is agreeable, we'll
# open the pac"
# if jim is agreeable, we'll
# open the paccaneer and the captain smollett to see the side of the stribure, and the ship of the captain smollett to hears to the string. and the ship of the captain and the captain smollett to see his hand. the captain smotty the worst of the stores of the strength of the ship, and then the streng of the strength of the ship of the ship of the stribicl.
#
# "the ship, and i stood the captain had to see his ha
# ----- temperature: 0.5
# ----- Generating with seed: "if jim is agreeable, we'll
# open the pac"
# if jim is agreeable, we'll
# open the paccaneer in a fift to be for his hand. i was a second great deal under the sun before i was no hand."
#
# "the neith of them, said the captain, and the let
# here silver, like a man not on his face some deal
# me, and a man at short i short of a face.
#
#     "thy was not so it, sir, with a man the staps
# and the captain, but this the stricked to the sun came them to till the light of the hollord and ch
# ----- temperature: 1.0
# ----- Generating with seed: "if jim is agreeable, we'll
# open the pac"
# if jim is agreeable, we'll
# open the paccaneer a blow but with the meranstred him and
# from the anchorages countly blueged make it.
# there'se down, at len," givens, that's silver every hindment," hast, i can't up to commetture--cheesile.
#
# colar not all they had a man, i project cast; or only holting the hand to sefounded reduch,
# backed tim his hand. sird, for that clun
# if his port nothing to fight! now thed slow douth?" he added," h
# ----- temperature: 1.2
# ----- Generating with seed: "if jim is agreeable, we'll
# open the pac"
# if jim is agreeable, we'll
# open the paccu's of them, but busy to the wating his ."
#
# "new _must georgeve his way blueleds--stage, and,      ny oneave taer. breat, _hissely just, and, he, and shortly were admin, and seen wo, i are, i silver, squire at the ."
#
# "theyo, mack ears."
#
# pewing to moke hanging the hind--ca king awayquenes, and for you forget. i'll
# quife in times orugh to round poor of pupsiral
# out o'flisen that fog turni
# Epoch 17/60
# 1035/1035 [==============================] - 33s 32ms/step - loss: 1.2303
# ******************************************************
# ----- Generating text after Epoch: 16
# ----- temperature: 0.2
# ----- Generating with seed: "lly in my
# breast.
#
# "lad," said silver"
# lly in my
# breast.
#
# "lad," said silver, "that's the sails in the ship was a strong smotionss to the ship was all the blockhouse the doctor. it was a side in the ship was all the stockade. it was a sea-chipter and the ship of the man we had soon step to the man we had the same tom the ship was all the ship was all the ship was all the blockhouse of the ship was a strong the ship was the ship was allow the work would as it was the ship
# ----- temperature: 0.5
# ----- Generating with seed: "lly in my
# breast.
#
# "lad," said silver"
# lly in my
# breast.
#
# "lad," said silver, "that's a word of neere and forth for the pretty of the works than the rest; it would have the bows. the door for the sand. it was so full to the horsey face as a currade, and the
# word he was position, the stockade of the doctor and the sound at once.
#
# "fired on the ship--and the doctor had the lenght of the countrer for you the ble side,
# the blockhouse, and he say to this the captain
# was a
# ----- temperature: 1.0
# ----- Generating with seed: "lly in my
# breast.
#
# "lad," said silver"
# lly in my
# breast.
#
# "lad," said silver,"
#      all there were for there head was utenged gentlemardes. the chists on you' her yeat.
#
# shipter from sort!, and if i could not about a bearler--lenyul were be one lante onlas,
# frighwandy that defore was down. hot you could
# ever tterement, now set down the derief of
# fird, but the preanting for -day, and me incled' and waymen matter, by the bldick likied back a
# sort and youn't was foth
# ----- temperature: 1.2
# ----- Generating with seed: "lly in my
# breast.
#
# "lad," said silver"
# lly in my
# breast.
#
# "lad," said silver," he saided-madmen, like a ligst foots hand."
#
# thdmp i could see had the wind now along the perflegge, who i cried
# wroon's countain, and yourselfy,  like a northplieeve, they lel what we now
# lose the current; len's lost them nell takeoning. continut!
#
# it, you could elarated up, i've thet he sperrily strong for peracle as it's this side, "before trivor.
# "it must'l' do roat. "most, what it."
# Epoch 18/60
# 1035/1035 [==============================] - 36s 34ms/step - loss: 1.2248
# ******************************************************
# ----- Generating text after Epoch: 17
# ----- temperature: 0.2
# ----- Generating with seed: "istened, so
# let her stay, i says. so it"
# istened, so
# let her stay, i says. so it was a strong the captain and all the stockade and shoutan of the ship
# showed the stockade and shoutant and the captain as i should seen the captain, and the ship of the streeled from the said to seen and founded and called at the short of the streams of the ship of the ship of the captain as i was a ship, and when i saw to seen the captain
# and the captain as i should be guination. the captain,
# ----- temperature: 0.5
# ----- Generating with seed: "istened, so
# let her stay, i says. so it"
# istened, so
# let her stay, i says. so it was a ship of the last of the same
# man to seen good of the one of the short of set sea whole sailed the captain, and come, and about sea. i should be fultion
# the coust; and all the said it was where i a heart and could been more was again, and the ruling from the took to me with a way of the deck.
#
# broment beyend at the ship beford it by the thress of the four and the spit.
#
# and project gut
# ----- temperature: 1.0
# ----- Generating with seed: "istened, so
# let her stay, i says. so it"
# istened, so
# let her stay, i says. so it would i was lasten toubry above, canner the hand, and a courted about the project
# gutenberg"thime craig to
# all not runnume each put when from adoth."
#
# but all aftery, it would say and again," said silver. "i ferrst three
# lutes over slasch to ble for uponing that after sablesside, with
# himself mags, and deck, sound the mainane his way a retorhid in the hears
# shrow? no, darter."
#
# feor four
# ----- temperature: 1.2
# ----- Generating with seed: "istened, so
# let her stay, i says. so it"
# istened, so
# let her stay, i says. so it posy that it," and
# jaiss. i began fanced down of usting breakhoar.
#
# we donaty sewardal kence full furtwhonstrn, on his
# town the foust's schoof doon, and there' werrs, who had
# suddenly into my abcafit.
#
# ences?"
#
# at deserd, to sy greatly sigger, i
#        thot but we spired ooctude of inverthing
# offcran!" sanrribch, up with engightmint, whistle stoop
# instious nearitioah all the innorpiem
# Epoch 19/60
# 1035/1035 [==============================] - 36s 35ms/step - loss: 1.2171
# ******************************************************
# ----- Generating text after Epoch: 18
# ----- temperature: 0.2
# ----- Generating with seed: "f us with a brace of pistols each.
# if a"
# f us with a brace of pistols each.
# if a sive been and the captain.
#
# "and the captain, "that's the captain, "that's the captain.
#
# "well," said he, "ben, john," said the doctor.
#
# "why, why, why, why, silver there's a man manner the captain
# and the captain spitch and the seaman of the water.
#
# "well," said he, "be benbort was a long captain still and the same more of the
# ship, and the captain had sunded the captain.
#
# "well," sa
# ----- temperature: 0.5
# ----- Generating with seed: "f us with a brace of pistols each.
# if a"
# f us with a brace of pistols each.
# if a said it was a mann and sails to the squire.
#
# "my mater," said he, "that's doon's benbow, if it, and the corror of the works of and the captain.
#
# "and the captain spirits, i was man instiles ebooks, and the more were and
# each of this works in the woods with as i hadd; and there's a sive sharpled to the water, which had taken its
# way of the side of the first was breakfain and
# swamplinges, an
# ----- temperature: 1.0
# ----- Generating with seed: "f us with a brace of pistols each.
# if a"
# f us with a brace of pistols each.
# if a carrent colles. the anchopage and stage in. i
# found him, which i stole of cap'n the how of agair!" he say nothing that all ownsurs gone' camp of to oft under it.
#
# i was g whoter sready, that were mom.
#
# "and we'll be you, for the cowams he had old keep his
# own ut--the
# calk of saft, and for so ring and point,
# not if cleans.
# to the east!" added, as if itwain open fromting. this attroor coul
# ----- temperature: 1.2
# ----- Generating with seed: "f us with a brace of pistols each.
# if a"
# f us with a brace of pistols each.
# if a poor about air. not weatory's no wattpe. m."
#
# "neyl', it's by jobly again," reneve slowlighty back, forty in a now, and about, and all ran
# forty fell bustle of seilling. and do he
# clombs, brave, "that', this enn wryen thrave of them?" im ranomed.
#
# ah!, eke."
#
# an jovan alars fettes. there."
#
# "quiethy," say over was eversever seemed. i was
# sough under the swater, "not, "sliving that move
# Epoch 20/60
# 1035/1035 [==============================] - 35s 34ms/step - loss: 1.2132
# ******************************************************
# ----- Generating text after Epoch: 19
# ----- temperature: 0.2
# ----- Generating with seed: ", for i was
# determined to go down the s"
# , for i was
# determined to go down the same was of the ship of the ship of the ship of the ships
# with the ship i say the ship we was still had the ships of the ship of the man of the ships, and i say the man made me than and should seemed the ship we were all the bow of the shore was so that the ship
# been a side of the ship i say the was of the ship of the ship of the same moment before the same moment and the same us and the ships of
# ----- temperature: 0.5
# ----- Generating with seed: ", for i was
# determined to go down the s"
# , for i was
# determined to go down the stern and began to constant
# order for sure the house should have got the was
# them had a man me with the old from the side in a moment there were breakfor good from
# an shook, and then i suppose the seamen and get the word or fort,
# and we were was round it as the men, and then they was the sand. and he would not could have heard
# strong the treasure men that missily and so my eash. and i began to
# ----- temperature: 1.0
# ----- Generating with seed: ", for i was
# determined to go down the s"
# , for i was
# determined to go down the spy-glass, in my bows, infect.
#
# all then we we board, as she is," replosed, you far omenpose holler, hail ob. was
# nogesil had natrricked at a moment on the mutch. we. inds
# with run" manace, with a hoon iuse.  the man would be writons, i ran, spot and mortaling.
#
# at moas time there. "i'm the side, i lrewernn't silver, and."
#
#  i  the lash you hawkins hand her. the atiley, that the hisself to
# ----- temperature: 1.2
# ----- Generating with seed: ", for i was
# determined to go down the s"
# , for i was
# determined to go down the shoreward finger trans i herus
# on
# now; hings he had made i had crost hour abcpositien, drippled theirs. "noch must;. down
# each voyard.
#
#  n id had never sudden; and if you stupme out and musket, but
# agriee my head mongonationation-joure, would right for retinger matt from
# plancy. thust you sad mo much and was lose the
# jomens. receiation.
#
# the feel maninesperace. and how hand, full there we
# Epoch 21/60
# 1035/1035 [==============================] - 35s 34ms/step - loss: 1.2074
# ******************************************************
# ----- Generating text after Epoch: 20
# ----- temperature: 0.2
# ----- Generating with seed: "er jacket, as they called
# the stout tar"
# er jacket, as they called
# the stout tarropen of the streeleth.
#
# "well, then, said, "i'm all the same that the same man of the same man of the strain
# of the streeles, and the same man of the ship had a man
# on the store of the streelething to the ship in the streel of the streelet.
#
# "that's a side he had been the same man to be to have the work or to be to me, and the stockade
# of the captain still to a hot in the ship in the shore
# ----- temperature: 0.5
# ----- Generating with seed: "er jacket, as they called
# the stout tar"
# er jacket, as they called
# the stout tarropping of the wood as forged him.
#
# "ay, another brief he was struck to see him and clean
#
#  lost no him in the house and which he were side them."
#
# it was discoring him to his concilutly surprise no more.
#
# at the soon the captain island, and, they could as the lives and all the door, and i had
# show his mouse of ran many--the sea-boo conspand of the captain of the sudden, and the captain s
# ----- temperature: 1.0
# ----- Generating with seed: "er jacket, as they called
# the stout tar"
# er jacket, as they called
# the stout tarlish. twhind a mann of hundred that we had solwarded, i would loupt lives be
# done for time that it--tih, like the doctor.
#
# it in a project gutenbergs
# sonely of to remumbars, you skelon is dererchion. tobary if withouting, pitch, and if one of their cleim relling into the blind
# waith it at hill in the hepmanion.
#
#
# though, and ho-hole craple summoliently and 'ush if a freeces.
#
# it was lin
# ----- temperature: 1.2
# ----- Generating with seed: "er jacket, as they called
# the stout tar"
# er jacket, as they called
# the stout tardering driwing.
#
# all ever talking, "and not yo-kn', cap, "that
# before when i paug selve meictles eating. there's a side you
# shiw calment hardly was in it rustes as he
# showing eveninge, stand to the water, stopper,
# cor'il for you! bug, by thunking together, not by jim,
# whenot."
#
# what it his ancaviog
# silver."
#
# that you areve i talk on one of thanoler
# ...
# Epoch 54/60
# 1035/1035 [==============================] - 35s 34ms/step - loss: 1.1067
# ******************************************************
# ----- Generating text after Epoch: 53
# ----- temperature: 0.2
# ----- Generating with seed: "the
# light airs which had begun blowing "
# the
# light airs which had begun blowing the spiries of the ship to the mouth of the spy-glass of the wind
# the stores of the blind and before the spirits to be to the man with the ship in the ship i tell you a rest of the captain, and the captain smollett. the squire and the spy-glass of the spiries of the spiries of the woods in the ship i had been still
# to see the man we stood the blind and the captain
# and the same moment; and the s
# ----- temperature: 0.5
# ----- Generating with seed: "the
# light airs which had begun blowing "
# the
# light airs which had begun blowing a day,
# and the word, and i thought; and before the corling head in the slee. it were the relly the woods had down the head the dead but my meticon and the onlifion
# through the cabin, with a great first to the using to my ears merance as if that my mother in the stockade and danged to the sound
# that the parlory was still trust in the sperking.
#
# "doctor livesey, and they step down the captain w
# ----- temperature: 1.0
# ----- Generating with seed: "the
# light airs which had begun blowing "
# the
# light airs which had begun blowing till you. well,
# i'll purned it each still con. i were, he says
# thele came heat his both for me by tall samile,
# old myself of the captain, "ven our absued,
# inctor oper, "if we so name a blow my revious like
# him i do, he old kinse. the musket head his
# party mindical aim; and was
#  the placiag towe of the captain looped island.
#
# "hew." i would have ached the schooner dad fingers parking out
#
# ----- temperature: 1.2
# ----- Generating with seed: "the
# light airs which had begun blowing "
# the
# light airs which had begun blowing therewsk their swill; and in nrombug for,
# in the mutiny mysavece in my hear themx; that mo did like
# on the squire. "you see you in that, jim howed him to the
# boty men gone--this brief prourr. i was miss not know, check
# vensured, the pold shore, and now, feew that you
# thoughty began to ut, my firenn. it was all who had know
# nos youmds. but had two an oddicane was purce for parging
# indict, hi
# Epoch 55/60
# 1035/1035 [==============================] - 34s 33ms/step - loss: 1.1096
# ******************************************************
# ----- Generating text after Epoch: 54
# ----- temperature: 0.2
# ----- Generating with seed: "sit quietly where they were and hark bac"
# sit quietly where they were and hark back to the captain
# steady to the way and a man when the man when the sound of the ship.
#
# and the captain had so stayd upon the stockader in the ship. it was the captain was for a second of the captain
# and the captain was still hands to the bottom of the man who had said the color who had so far surprise.
#
# we made me a command, and the same man when the man man the captain
# and the captain was
# ----- temperature: 0.5
# ----- Generating with seed: "sit quietly where they were and hark bac"
# sit quietly where they were and hark back to
# the sea which the worst of the side of the house, and the captain
# and a mile between the sign of the seaman
# and the boat with a rum before we stood all the place before the same moment, and we man afraid to me that was
# shorther and left beside the worst of the same lue lay a wite a look of
# the liep of the man with his power sones soon
# the side of the widder; the dead for make me, the sa
# ----- temperature: 1.0
# ----- Generating with seed: "sit quietly where they were and hark bac"
# sit quietly where they were and hark back to see his
# clear. the step e had recassed about on an
# ending to silver and the jolly
# of on the chopage?"
#
# the number ly our ear terrows.
#
# "he could do. well, belly -fellers for weal that arms commass bangainly loud
# below flip my seate man, he so he take at bill--a blask
# repert me, was lose fair rushen't word, jim. as mother was
# up the worst of the norselo stupped, threster hor and the
# ----- temperature: 1.2
# ----- Generating with seed: "sit quietly where they were and hark bac"
# sit quietly where they were and hark back the quarmiting forwarms neipten of make instantly colarmers pipe for you're feex:
#
# an" there," said i?" he hererfinsarly but rup, and another true che
# sea. the other. plashed all
# and you of our shon. to leastly, with
# anyaby the whroticales laying, of nuppoore.
#
# we lectoon us.
#
# let the wlashing a clinging board ever their concemy-awarning, but the
# terie here with a his recent or endle a
# Epoch 56/60
# 1035/1035 [==============================] - 34s 32ms/step - loss: 1.1009
# ******************************************************
# ----- Generating text after Epoch: 55
# ----- temperature: 0.2
# ----- Generating with seed: "s loan of the torch.
# silver briefly agr"
# s loan of the torch.
# silver briefly agreeved the captain he spirits.
#
# "and i thought i had have been the spit the spit of the ship of the ship, and then i had
# always to the doctor, when the man we shot in the ship.
#
# "who's the captain he said he, and when we were all the captain would be took the captain, and the spy-glass in the ship.
#
# "who'll see the squire and the more the coast and the sones of the captain
# something the wor
# ----- temperature: 0.5
# ----- Generating with seed: "s loan of the torch.
# silver briefly agr"
# s loan of the torch.
# silver briefly agreeved the captain, and
# word to called to the door of the time he said have been was the ship.
#
# it was no old father, and the captain was to stand they as if the captain
# stood all of the ship. and i should hel, spitting the work of his clouner of the ship. it was all don't to
# crewled a straing to speed with the ship.
#
# "boyce," said he, "the squire and the some in the window of the blind appe
# ----- temperature: 1.0
# ----- Generating with seed: "s loan of the torch.
# silver briefly agr"
# s loan of the torch.
# silver briefly agries,-"ah, gray, "and then, he shoution
# to came upon when inwere mvain, instance.
#
# and congossion, the laptain, in a changing of the electronic work of al!
# the whry count, and if did, it bill jonk yop, i shove
# were greern over his eyes and during. for
# mighte--prise the rose nor day. if you laug with me
# in."
#
#
#
#
# chapter we soon have chells. back a supplier at streech
# and of you feet fea
# ----- temperature: 1.2
# ----- Generating with seed: "s loan of the torch.
# silver briefly agr"
# s loan of the torch.
# silver briefly agreak of me nearer, he took the ."
#
# in the doctor of thede bapleowl upon the loop of a sheew and trais bove
# if mide of me, could say, my own mostry round
# captuinlift. as moadinath i casst, spot like spearlentward against out of her. the glase some
# lick, liftering knowly, and randle.   his cheese before, for
# ow me," replainly--with norther awoud of the ginny:
#
# "drewn'tm craant." reliallight,"
# Epoch 57/60
# 1035/1035 [==============================] - 34s 33ms/step - loss: 1.1027
# ******************************************************
# ----- Generating text after Epoch: 56
# ----- temperature: 0.2
# ----- Generating with seed: "
# that; but it's over and done. i'll tak"
#
# that; but it's over and done. i'll take a monsid. i could not be come to reture at the ship of the captain smollett. i had
# been stood of my own mates. i had not so far speried and spirits, and i had a good more still hand. he was no stulled them we had sound the captain smollett. i had
# been swabpo-sain him that i should have thought the words of the blind bear. i
# broke out of a ships, and then, we made the spit on a sudden, and the
# ----- temperature: 0.5
# ----- Generating with seed: "
# that; but it's over and done. i'll tak"
#
# that; but it's over and done. i'll take a mount know a moment the squire and one in the surright, and then i had
# been sorterned to make a commass of the indered for the ship
# of the souther firse of spiries of the speriied and a long blind before the chart, and my shot into
# silving by the sudders. as i had help a way after sealing and speak out, and i was done my ears that my mother was
# them to parking with a till the charger who a
# ----- temperature: 1.0
# ----- Generating with seed: "
# that; but it's over and done. i'll tak"
#
# that; but it's over and done. i'll take nothing. but lhat here rath're--speak, to feel and pieted by thres rallibgtt took townce and still as we did.
#
# "that's count hel, you were no should have george. who my adviquitd over the part of the others
# wormen."
#
# he went these, and cate jut leadence of be cap, and lill, and shar'k like you afrood sow,s--as all seemed him,g his ong through in the pipe. we
# are adrived, doctor. if it was
# ----- temperature: 1.2
# ----- Generating with seed: "
# that; but it's over and done. i'll tak"
#
# that; but it's over and done. i'll take de-tall.
#
# "i can'n and so much you have very been, said, , was the light. hide.  ccours
# on these key me left, i would be cursed round and you'll,
# and my mothers---as then, hawsny upbott one paming captain devil, fighing accessnoor memard, sitting vainr of good of."
#
# we's meting domind, and ne this anchorage
# wather to not wound. some weith in one your, pround 'em, said paying morgan, and,
# Epoch 58/60
# 1035/1035 [==============================] - 33s 32ms/step - loss: 1.1005
# ******************************************************
# ----- Generating text after Epoch: 57
# ----- temperature: 0.2
# ----- Generating with seed: "as," says silver.
#
# the doctor stopped "
# as," says silver.
#
# the doctor stopped at the same man for the captain
# adventure it was a good me that he said, and the same man for
# me the worst of the strestkers. as shore of the captain, "who had the same man for
# the marons we were a man me on the cabin the same moment his ear a man whother was a constate for me along the ship of the ship.
#
# "this is to see him as i had had to thounded by the same moment and the chart. the capta
# ----- temperature: 0.5
# ----- Generating with seed: "as," says silver.
#
# the doctor stopped "
# as," says silver.
#
# the doctor stopped me for a blocks of the blowing a man who thought i pusted the more was steeplinged for a constate for the chift, and the fire. had
# not say crackling to me the same man for the
# toms let it. but a play hunter and the captain of was among at his cracking and
# bulled up the blind man for geathen in the side of the worst of the same moment his will. the more than i was a sailor
# with whater to silvin
# ----- temperature: 1.0
# ----- Generating with seed: "as," says silver.
#
# the doctor stopped "
# as," says silver.
#
# the doctor stopped athough, and that i had drawing my ords, with on' le."
#
# "well," said i, "though his strengthem, there were
# its black in my post fallen and stallow a musted hold in my honst comes to much got me in this
# time we did, i had no  short ofer; dischiof; the  and in the head words had obcived, but the
# bars leave. i had have reserted himskilechions; puttorch, and you neyver
# my reaioness. then you fee
# ----- temperature: 1.2
# ----- Generating with seed: "as," says silver.
#
# the doctor stopped "
# as," says silver.
#
# the doctor stopped up at his upoen as he dripuded
# and tymounk
# to made her ondices as a peyed fiftagn.
#
#     "don't criel, i left boor; now? at he i say.
#
# by foum chose of sand, and dickmanding to again
# to a side attreed tooders. i spir.
#
# and at left darging, in a clouse, one look on roar. at the first dre.
#
# "us"," said he." i'ble on a pird--our way me at his tim
# a cleal flapposiin, neither hawkins. what w
# Epoch 59/60
# 1035/1035 [==============================] - 35s 34ms/step - loss: 1.1013
# ******************************************************
# ----- Generating text after Epoch: 58
# ----- temperature: 0.2
# ----- Generating with seed: "
#
# "budge, you skulk!" cried pew. "dirk "
#
#
# "budge, you skulk!" cried pew. "dirk if you say, i could not conting of the spit on the ship of the ship of the ship
# he had the ship, i that i was still the captain still the worst propate in the strengthing to the ship i set met to and the captain she was a ship in the ship, and then
# the captain slass to the treasure island, and the said in the strugg and the ship in the strugg of the spit on a suppled and all the blockhouse for t
# ----- temperature: 0.5
# ----- Generating with seed: "
#
# "budge, you skulk!" cried pew. "dirk "
#
#
# "budge, you skulk!" cried pew. "dirk if you say to see it set of them in the sentry
# port perhaps, and i had the ship of the doctor, which i the whreed and distribution,
# and we my hands and brought on the course of the ship was
# sent theme notion i had to saids i have heard it
# doctor livesey, while i had a confoundes, and then you stand of
# the old ship i made you the whist i was ruines, and then
# cold in the arms of the dead was a
# ----- temperature: 1.0
# ----- Generating with seed: "
#
# "budge, you skulk!" cried pew. "dirk "
#
#
# "budge, you skulk!" cried pew. "dirk me,'s told he sailor, for
# north man."
#
# i said, and i had was a great and and i lunt him, but when, could
# can my musk out in our self warn tell and furied hame; and if em-ering told, peach
# argate on one to long with thems. "you have their truticing--it was talk by the project gutenbergs
# pleased, had accidentunt. all the copyridg soat and some with him, no proacabed the
# sing, and, with no wor
# ----- temperature: 1.2
# ----- Generating with seed: "
#
# "budge, you skulk!" cried pew. "dirk "
#
#
# "budge, you skulk!" cried pew. "dirk you among the maroom for the mast
# hunters he were shore, tire, but set me, relicy loak.
#
# "i'll draw," read to treasure officer," canes,  spe"if her ope read i agreaded, sometimes cutlassarferulls, by
# thistanger; onck," he cried to him dry, kind the
# blught. "i pirecies is. fithty last, some to the apped, gray,
# and.
#
# i wadfentily, in alevenn.  freal made that
# office as blash 't turning, "th
# Epoch 60/60
# 1035/1035 [==============================] - 33s 32ms/step - loss: 1.0970
# ******************************************************
# ----- Generating text after Epoch: 59
# ----- temperature: 0.2
# ----- Generating with seed: " hole the lugger was already under way, "
#  hole the lugger was already under way, and something before the captain.
#
# "why spie to my doctor," said iy that doctor livesey came for the ship of the spiring at the same men sailor
# haster and the trees to be benborly and sound
# the captain, and the captain had been stopped on the spit.
#
# "now, i don't it was a sudden, and the squire and spirits of the sun for the southeres, and then i saw him the captain.
#
# "i save the sand, doc
# ----- temperature: 0.5
# ----- Generating with seed: " hole the lugger was already under way, "
#  hole the lugger was already under way, and sometimes as if this back at the captain, and then i looked the ship, it
# was still bunner, and i was done by the same more in the ship of our to father
# was terrors and looked and the lightsomen of the incerve
# aglivened to him some remarkan by the fire, and he say over the first of the fire
# in the captain as he was a bit of enough of the project
# gutenberg thad all the door of the side of t
# ----- temperature: 1.0
# ----- Generating with seed: " hole the lugger was already under way, "
#  hole the lugger was already under way, and grosc-strutg, excount or uplain accors of ship, wethping to and to skill took her tis main back in the bird and smothing
# on thes. as if i trind the capters hungne.
#
# and neatly pale better to make pruting blighg. and that with how that she fad
# stood by that was an ashiblarching through me in the legge rast 'le
# there nover and silling pocket.
#
#     "that, as come to have man dold on my
# eo
# ----- temperature: 1.2
# ----- Generating with seed: " hole the lugger was already under way, "
#  hole the lugger was already under way, had come
# than the excrapy tiffere his lost by lost evering easte trunion.
#
# elechious from chiscution farter of the handses.
#
#  i had rum to now sand, with stroinds it
# dead harmeltrom. the hore up?" cried ones, "i savery like a repeated, but
# ony, and though yet thew-spate away percapes
#      of spylose. the head time; and
# fair alspowo's sxmet and feuran, spiny-'seamed him as tell it houre on
